# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import geopandas as gpd
import pysal
# %matplotlib inline

# %%
humboldt_park = gpd.read_file("data/humboldt-park/humboldt-park.geojson")
humboldt_park["area"] = humboldt_park["geometry"].area
humboldt_park.head()
# Out:
#                                             geometry   neighborhood      area
# 0  POLYGON ((-87.68707752227783 41.91032572790956...  humboldt-park  0.000320
# 1  POLYGON ((-87.74608612060547 41.90968698030152...  humboldt-park  0.001431
# 2  POLYGON ((-87.68677711486815 41.89582458304622...  humboldt-park  0.000345
# 3  POLYGON ((-87.6873779296875 41.91415807933598,...  humboldt-park  0.000720
# 4  POLYGON ((-87.68694877624512 41.91805406740491...  humboldt-park  0.000574

# %%
hp_intersects = humboldt_park["geometry"][5].intersection(humboldt_park["geometry"][1])
print hp_intersects
# Out:
# POLYGON ((-87.68680779355323 41.89045345823286, -87.72600173950195 41.89001042401827, -87.72650729163038 41.90989937774629, -87.68720626831055 41.91032572790956, -87.68680779355323 41.89045345823286))

# %%
def get_intersections(gdf, idx):
    i_gdf = []
    for i, val in enumerate(gdf["geometry"]):
        if not idx == i and gdf["geometry"][i].is_valid:
            inter = gdf["geometry"][idx].intersection(gdf["geometry"][i])
            inter_dict = {
                "orig": idx,
                "inter": i,
                "geometry": inter,
                "area": inter.area
            }
            i_gdf.append(inter_dict)
    return pd.DataFrame(i_gdf)

# %%
hp_test_intersect = get_intersections(humboldt_park, 5)
hp_test_intersect[:10]
# Out:
# Self-intersection at or near point -87.71170156851403 41.904652090768906
# WARNING:shapely.geos:Self-intersection at or near point -87.71170156851403 41.904652090768906
#        area                                           geometry  inter  orig
# 0  0.000317  POLYGON ((-87.68715523255919 41.91032510606678...      0     5
# 1  0.000780  POLYGON ((-87.68680779355323 41.89045345823286...      1     5
# 2  0.000344  POLYGON ((-87.7054415663806 41.89024282879227,...      2     5
# 3  0.000719  POLYGON ((-87.72660255432127 41.9136471124402,...      3     5
# 4  0.000438  POLYGON ((-87.68729209899902 41.91409420869771...      4     5
# 5  0.000570  POLYGON ((-87.72618416085484 41.89718707236523...      6     5
# 6  0.000603  POLYGON ((-87.72660137829735 41.91364712581566...      7     5
# 7  0.000523  POLYGON ((-87.68729209899902 41.91409420869771...      8     5
# 8  0.000208  POLYGON ((-87.70668983459473 41.89831620347219...      9     5
# 9  0.000314  POLYGON ((-87.68718001480042 41.91100757293528...     10     5

# %%
humboldt_park["valid"] = humboldt_park["geometry"].is_valid
#humboldt_park["valid"] == False
humboldt_park[:10]
# Out:
# Self-intersection at or near point -87.71170156851403 41.904652090768906
# WARNING:shapely.geos:Self-intersection at or near point -87.71170156851403 41.904652090768906
#                                             geometry   neighborhood      area  \
# 0  POLYGON ((-87.68707752227783 41.91032572790956...  humboldt-park  0.000320
# 1  POLYGON ((-87.74608612060547 41.90968698030152...  humboldt-park  0.001431
# 2  POLYGON ((-87.68677711486815 41.89582458304622...  humboldt-park  0.000345
# 3  POLYGON ((-87.6873779296875 41.91415807933598,...  humboldt-park  0.000720
# 4  POLYGON ((-87.68694877624512 41.91805406740491...  humboldt-park  0.000574
# 5  POLYGON ((-87.68729209899902 41.91409420869771...  humboldt-park  0.000933
# 6  POLYGON ((-87.68724918365479 41.91032572790956...  humboldt-park  0.000571
# 7  POLYGON ((-87.68733501434326 41.91397445107869...  humboldt-park  0.000604
# 8  POLYGON ((-87.71556713181781 41.89570153118875...  humboldt-park  0.000649
# 9  POLYGON ((-87.70668983459473 41.89831620347219...  humboldt-park  0.000208
#
#   valid
# 0  True
# 1  True
# 2  True
# 3  True
# 4  True
# 5  True
# 6  True
# 7  True
# 8  True
# 9  True

# %%
from __future__ import division

def get_mean_overlap(gs, idx):
    overlap_list = []
    
    if not gs["geometry"][idx].is_valid:
        return 0
    
    for i, val in gs.iterrows():
        if not idx == i and gs["geometry"][i].is_valid:
            intersection = gs["geometry"][idx].intersection(gs["geometry"][i])
            overlap_pct = intersection.area / gs["geometry"][idx].area
            overlap_list.append(overlap_pct)
    
    return sum(overlap_list) / len(overlap_list)

# %%
dna_info = gpd.read_file("dna_neighborhoods.geojson")
dna_info.head()
# Out:
#                                             geometry neighborhood
# 0  POLYGON ((-87.68754959106445 41.92488743920406...     bucktown
# 1  POLYGON ((-87.68772125244141 41.92693092226143...     bucktown
# 2  POLYGON ((-87.68763542175293 41.92725021057667...     bucktown
# 3  POLYGON ((-87.66776561737061 41.91074091042736...     bucktown
# 4  POLYGON ((-87.65356063842772 41.9112199638231,...     bucktown

# %%
dna_info["valid"] = dna_info["geometry"].is_valid
dna_info = dna_info[dna_info["valid"] == True]
dna_info[:25]
# Out:
# Self-intersection at or near point -87.686438916304667 41.910271695783507
# WARNING:shapely.geos:Self-intersection at or near point -87.686438916304667 41.910271695783507
# Self-intersection at or near point -87.788491453218157 41.98601286335942
# WARNING:shapely.geos:Self-intersection at or near point -87.788491453218157 41.98601286335942
# Self-intersection at or near point -87.729263305664062 41.983356261006165
# WARNING:shapely.geos:Self-intersection at or near point -87.729263305664062 41.983356261006165
# Too few points in geometry component at or near point -87.6424241065979 41.892278647917657
# WARNING:shapely.geos:Too few points in geometry component at or near point -87.6424241065979 41.892278647917657
# Self-intersection at or near point -87.662614948420355 41.944892143035375
# WARNING:shapely.geos:Self-intersection at or near point -87.662614948420355 41.944892143035375
# Self-intersection at or near point -87.630632952110147 41.866987407744745
# WARNING:shapely.geos:Self-intersection at or near point -87.630632952110147 41.866987407744745
# Self-intersection at or near point -87.656278069661781 41.965673971769824
# WARNING:shapely.geos:Self-intersection at or near point -87.656278069661781 41.965673971769824
# Self-intersection at or near point -87.651886333931159 41.973543484149701
# WARNING:shapely.geos:Self-intersection at or near point -87.651886333931159 41.973543484149701
# Self-intersection at or near point -87.645185495158671 41.954885875733162
# WARNING:shapely.geos:Self-intersection at or near point -87.645185495158671 41.954885875733162
# Self-intersection at or near point -87.696653134388384 41.975925779834952
# WARNING:shapely.geos:Self-intersection at or near point -87.696653134388384 41.975925779834952
# Self-intersection at or near point -87.703229443024071 41.965477682669018
# WARNING:shapely.geos:Self-intersection at or near point -87.703229443024071 41.965477682669018
# Self-intersection at or near point -87.717500791285502 41.941382570329075
# WARNING:shapely.geos:Self-intersection at or near point -87.717500791285502 41.941382570329075
# Self-intersection at or near point -87.787422365928435 41.970491745681166
# 8   POLYGON ((-87.68724918365479 41.91029379068096...     bucktown  True
# 9   POLYGON ((-87.66772270202635 41.91064509931678...     bucktown  True
# 10  POLYGON ((-87.68720626831055 41.91390259639942...     bucktown  True
# 11  POLYGON ((-87.68754959106445 41.924536208962, ...     bucktown  True
# 12  POLYGON ((-87.6679801940918 41.91019797889927,...     bucktown  True
# 13  POLYGON ((-87.68767833709717 41.92488743920406...     bucktown  True
# 14  POLYGON ((-87.68763542175293 41.92495129904035...     bucktown  True
# 15  POLYGON ((-87.67450332641602 41.92504708867493...     bucktown  True
# 16  POLYGON ((-87.68754959106445 41.9244404185604,...     bucktown  True
# 17  POLYGON ((-87.66420364379883 41.9112199638231,...     bucktown  True
# 18  POLYGON ((-87.68789291381836 41.93191163800078...     bucktown  True
# 19  POLYGON ((-87.68754959106445 41.92386567313071...     bucktown  True
# 20  POLYGON ((-87.68780708312988 41.92737792545533...     bucktown  True
# 21  POLYGON ((-87.67742156982422 41.91048541381291...     bucktown  True
# 22  POLYGON ((-87.67759323120116 41.91045347666418...     bucktown  True
# 23  POLYGON ((-87.65750885009764 41.91058122516316...     bucktown  True
# 24  POLYGON ((-87.68772125244141 41.92488743920406...     bucktown  True

# %%
dna_info["overlap"] = 0


for neighb in dna_info["neighborhood"].values:
    gs_neighb = dna_info[dna_info["neighborhood"] == neighb]
    for idx, row in gs_neighb.iterrows():
        dna_info["overlap"][idx] = get_mean_overlap(gs_neighb, idx)
# Out:
# /Users/pjsier/.virtualenvs/cps/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-baf1c1566e3d> in <module>()
#       5     gs_neighb = dna_info[dna_info["neighborhood"] == neighb]
#       6     for idx, row in gs_neighb.iterrows():
# ----> 7         dna_info["overlap"][idx] = get_mean_overlap(gs_neighb, idx)
#
# <ipython-input-2-0dd125a3c2c7> in get_mean_overlap(gs, idx)
#       9     for i, val in gs.iterrows():
#      10         if not idx == i and gs["geometry"][i].is_valid:
# ---> 11             intersection = gs["geometry"][idx].intersection(gs["geometry"][i])
#      12             overlap_pct = intersection.area / gs["geometry"][idx].area
#      13             overlap_list.append(overlap_pct)
#
# /Library/Frameworks/GEOS.framework/Versions/3/Python/2.7/site-packages/shapely/geometry/base.pyc in intersection(self, other)
#     561     def intersection(self, other):
#     562         """Returns the intersection of the geometries"""
# --> 563         return geom_factory(self.impl['intersection'](self, other))
#     564
#     565     def symmetric_difference(self, other):
#
# /Library/Frameworks/GEOS.framework/Versions/3/Python/2.7/site-packages/shapely/topology.pyc in __call__(self, this, other, *args)
#      64         self._validate(this)
#      65         self._validate(other, stop_prepared=True)
# ---> 66         product = self.fn(this._geom, other._geom, *args)
#      67         if product is None:
#      68             err = TopologicalError(
#
# KeyboardInterrupt:

# %%
list_neighborhoods = []

for val in dna_info["neighborhood"].values:
    list_neighborhoods.append(dna_info[dna_info["neighborhood"] == val])

for n in list_neighborhoods:
    n["overlap"] = 0
    for idx, row in n.iterrows():
        n["overlap"][idx] = get_mean_overlap(n, idx)
# Out:
# /Users/pjsier/.virtualenvs/cps/lib/python2.7/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/pjsier/.virtualenvs/cps/lib/python2.7/site-packages/ipykernel/__main__.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
